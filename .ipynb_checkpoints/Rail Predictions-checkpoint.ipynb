# %%
########### Python 3.2 #############
import http.client, urllib.request, urllib.parse, urllib.error, base64
import pandas as pd

key = open("keys.py").readline().replace("\n","")

# stationCode="J03"
stationCode="All"

headers = {
    # Request headers
    'api_key': key,
}

params = urllib.parse.urlencode({
})

try:
    conn = http.client.HTTPSConnection('api.wmata.com')
    conn.request("GET", "/StationPrediction.svc/json/GetPrediction/"+stationCode+"?%s" % params, "{body}", headers)
    response = conn.getresponse()
    data = response.read().decode('utf-8')
    print(data)
    conn.close()
except Exception as e:
    print("[Errno {0}] {1}".format(e.errno, e.strerror))

####################################
# Out:
# {"Trains":[{"Car":"6","Destination":"Shady Gr","DestinationCode":"A15","DestinationName":"Shady Grove","Group":"2","Line":"RD","LocationCode":"A02","LocationName":"Farragut North","Min":"BRD"},{"Car":"6","Destination":"Shady Gr","DestinationCode":"A15","DestinationName":"Shady Grove","Group":"2","Line":"RD","LocationCode":"A06","LocationName":"Van Ness-UDC","Min":"BRD"},{"Car":"6","Destination":"Shady Gr","DestinationCode":"A15","DestinationName":"Shady Grove","Group":"2","Line":"RD","LocationCode":"A11","LocationName":"Grosvenor-Strathmore","Min":"BRD"},{"Car":"8","Destination":"Glenmont","DestinationCode":"B11","DestinationName":"Glenmont","Group":"1","Line":"RD","LocationCode":"B01","LocationName":"Gallery Pl-Chinatown","Min":"BRD"},{"Car":"8","Destination":"Shady Gr","DestinationCode":"A15","DestinationName":"Shady Grove","Group":"2","Line":"RD","LocationCode":"B01","LocationName":"Gallery Pl-Chinatown","Min":"BRD"},{"Car":"6","Destination":"Glenmont","DestinationCode":"B11","DestinationName":"Glenmont","Group":"1","Line":"RD","LocationCode":"B04","LocationName":"Rhode Island Ave-Brentwood","Min":"BRD"},{"Car":"6","Destination":"Shady Gr","DestinationCode":"A15","DestinationName":"Shady Grove","Group":"2","Line":"RD","LocationCode":"B07","LocationName":"Takoma","Min":"BRD"},{"Car":"6","Destination":"Wiehle","DestinationCode":"N06","DestinationName":"Wiehle-Reston East","Group":"2","Line":"SV","LocationCode":"C04","LocationName":"Foggy Bottom-GWU","Min":"BRD"},{"Car":"8","Destination":"Frnconia","DestinationCode":"J03","DestinationName":"Franconia-Springfield","Group":"2","Line":"BL","LocationCode":"C05","LocationName":"Rosslyn","Min":"BRD"},{"Car":"6","Destination":"Largo","DestinationCode":"G05","DestinationName":"Largo Town Center","Group":"1","Line":"BL","LocationCode":"C07","LocationName":"Pentagon","Min":"BRD"},{"Car":"6","Destination":"Hntingtn","DestinationCode":"C15","DestinationName":"Huntington","Group":"2","Line":"YL","LocationCode":"C09","LocationName":"Crystal City","Min":"BRD"},{"Car":"8","Destination":"Largo","DestinationCode":"G05","DestinationName":"Largo Town Center","Group":"1","Line":"BL","LocationCode":"C13","LocationName":"King St-Old Town","Min":"BRD"},{"Car":"6","Destination":"Wiehle","DestinationCode":"N06","DestinationName":"Wiehle-Reston East","Group":"2","Line":"SV","LocationCode":"D01","LocationName":"Federal Triangle","Min":"BRD"},{"Car":"6","Destination":"NewCrltn","DestinationCode":"D13","DestinationName":"New Carrollton","Group":"1","Line":"OR","LocationCode":"D03","LocationName":"L'Enfant Plaza","Min":"BRD"},{"Car":"6","Destination":"Vienna","DestinationCode":"K08","DestinationName":"Vienna/Fairfax-GMU","Group":"2","Line":"OR","LocationCode":"D03","LocationName":"L'Enfant Plaza","Min":"BRD"},{"Car":"8","Destination":"Largo","DestinationCode":"G05","DestinationName":"Largo Town Center","Group":"1","Line":"BL","LocationCode":"D05","LocationName":"Capitol South","Min":"BRD"},{"Car":"6","Destination":"Grnbelt","DestinationCode":"E10","DestinationName":"Greenbelt","Group":"1","Line":"GR","LocationCode":"E02","LocationName":"Shaw-Howard U","Min":"BRD"},{"Car":"6","Destination":"Hntingtn","DestinationCode":"C15","DestinationName":"Huntington","Group":"2","Line":"YL","LocationCode":"E02","LocationName":"Shaw-Howard U","Min":"BRD"},{"Car":"6","Destination":"Hntingtn","DestinationCode":"C15","DestinationName":"Huntington","Group":"2","Line":"YL","LocationCode":"E06","LocationName":"Fort Totten","Min":"BRD"},{"Car":"6","Destination":"Brnch Av","DestinationCode":"F11","DestinationName":"Branch Ave","Group":"2","Line":"GR","LocationCode":"E09","LocationName":"College Park-U of MD","Min":"BRD"},{"Car":"6","Destination":"Ft.Tottn","DestinationCode":"E06","DestinationName":"Fort Totten","Group":"1","Line":"YL","LocationCode":"F01","LocationName":"Gallery Pl-Chinatown","Min":"BRD"},{"Car":"6","Destination":"Brnch Av","DestinationCode":"F11","DestinationName":"Branch Ave","Group":"2","Line":"GR","LocationCo ...

# %%
import json
z = pd.DataFrame(json.loads(data)['Trains'])

# %%
z.sort_values(['LocationName'])
# Out:
#       Car   Destination DestinationCode        DestinationName Group Line  \
# 357     8         Largo             G05      Largo Town Center     1   BL
# 24      6         Largo             G05      Largo Town Center     1   SV
# 445     6         Largo             G05      Largo Town Center     1   SV
# 248     6        Wiehle             N06     Wiehle-Reston East     2   SV
# 150     6      Frnconia             J03  Franconia-Springfield     2   BL
# 375     6      Frnconia             J03  Franconia-Springfield     2   BL
# 260     6       Grnbelt             E10              Greenbelt     1   GR
# 386     -         Train            None                  Train     2   --
# 261     6      Brnch Av             F11             Branch Ave     2   GR
# 424     6      Brnch Av             F11             Branch Ave     2   GR
# 291     -         Train            None                  Train     2   --
# 172     6       Grnbelt             E10              Greenbelt     1   GR
# 381     6       Grnbelt             E10              Greenbelt     1   GR
# 443     8      Ft.Tottn             E06            Fort Totten     1   YL
# 147     6      Hntingtn             C15             Huntington     2   YL
# 38      6      Brnch Av             F11             Branch Ave     2   GR
# 78      6         Largo             G05      Largo Town Center     1   BL
# 210     6      Frnconia             J03  Franconia-Springfield     2   BL
# 403     8      Frnconia             J03  Franconia-Springfield     2   BL
# 350     8         Largo             G05      Largo Town Center     1   BL
# 79      8      Frnconia             J03  Franconia-Springfield     2   BL
# 265     8      NewCrltn             D13         New Carrollton     1   OR
# 343     6         Largo             G05      Largo Town Center     1   SV
# 175     6         Largo             G05      Largo Town Center     1   SV
# 266     6        Wiehle             N06     Wiehle-Reston East     2   SV
# 344     8        Vienna             K08     Vienna/Fairfax-GMU     2   OR
# 176     8        Vienna             K08     Vienna/Fairfax-GMU     2   OR
# 262     8         Largo             G05      Largo Town Center     1   BL
# 62      6      Frnconia             J03  Franconia-Springfield     2   BL
# 292     6      Frnconia             J03  Franconia-Springfield     2   BL
# ..    ...           ...             ...                    ...   ...  ...
# 89      6       Grnbelt             E10              Greenbelt     1   GR
# 414     6      Brnch Av             F11             Branch Ave     2   GR
# 173     6      Brnch Av             F11             Branch Ave     2   GR
# 355     -         Train            None                  Train     2   --
# 341     6       Grnbelt             E10              Greenbelt     1   GR
# 416     6        Vienna             K08     Vienna/Fairfax-GMU     2   OR
# 122     8      NewCrltn             D13         New Carrollton     1   OR
# 397     8        Vienna             K08     Vienna/Fairfax-GMU     2   OR
# 307     8        Vienna             K08     Vienna/Fairfax-GMU     2   OR
# 404     6       Grnbelt             E10              Greenbelt     1   GR
# 88      6       Grnbelt             E10              Greenbelt     1   GR
# 171     6      Brnch Av             F11             Branch Ave     2   GR
# 303     6       Grnbelt             E10              Greenbelt     1   GR
# 103     6      Glenmont             B11               Glenmont     1   RD
# 406     8      Glenmont             B11               Glenmont     1   RD
# 372     6      Glenmont             B11               Glenmont     1   RD
# 71      8      Glenmont             B11               Glenmont     1   RD
# 98      6      Shady Gr             A15            Shady Grove     2   RD
# 231     8      Glenmont             B11               Glenmont     1   RD
# 252     8      Shady Gr             A15            Shady Grove     2   RD
# 333     8      Shady Gr             A15            Shady Grove     2   RD
# 130     6      SilvrSpg             B08          Silver Spring     1   RD
# 69   None  LARGO CENTER             G05      Largo Town Center     2   SV
# 68   None  LARGO CENTER             G05      Largo Town Center     1   SV
# 126     6      Shady Gr             A15            Shady Grove     2   RD
# 271     8      Glenmont             B11               Glenmont     1   RD
# 41      6      SilvrSpg             B08          Silver Spring     1   RD
# 347     8      SilvrSpg             B08          Silver Spring     1   RD
# 203     8      Shady Gr             A15            Shady Grove     2   RD
# 399     8      Shady Gr             A15            Shady Grove     2   RD
#
#     LocationCode                         LocationName  Min
# 357          G03           Addison Road-Seat Pleasant   14
# 24           G03           Addison Road-Seat Pleasant  BRD
# 445          G03           Addison Road-Seat Pleasant
# 248          G03           Addison Road-Seat Pleasant    8
# 150          G03           Addison Road-Seat Pleasant    4
# 375          G03           Addison Road-Seat Pleasant   16
# 260          F06                            Anacostia    9
# 386          F06                            Anacostia   18
# 261          F06                            Anacostia    9
# 424          F06                            Anacostia   29
# 291          F02  Archives-Navy Memorial-Penn Quarter   10
# 172          F02  Archives-Navy Memorial-Penn Quarter    5
# 381          F02  Archives-Navy Memorial-Penn Quarter   17
# 443          F02  Archives-Navy Memorial-Penn Quarter
# 147          F02  Archives-Navy Memorial-Penn Quarter    4
# 38           F02  Archives-Navy Memorial-Penn Quarter  ARR
# 78           C06                   Arlington Cemetery    2
# 210          C06                   Arlington Cemetery    7
# 403          C06                   Arlington Cemetery   22
# 350          C06                   Arlington Cemetery   14
# 79           C06                   Arlington Cemetery    2
# 265          K04                          Ballston-MU    9
# 343          K04                          Ballston-MU   13
# 175          K04                          Ballston-MU    5
# 266          K04                          Ballston-MU    9
# 344          K04                          Ballston-MU   13
# 176          K04                          Ballston-MU    5
# 262          G01                         Benning Road    9
# 62           G01                         Benning Road    1
# 292          G01                         Benning Road   10
# ..           ...                                  ...  ...
# 89           F04                           Waterfront    2
# 414          F04                           Waterfront   25
# 173          F04                           Waterfront    5
# 355          F04                           Waterfront   14
# 341          F04                           Waterfront   13
# 416          K06             West Falls Church-VT/UVA   25
# 122          K06             West Falls Church-VT/UVA    3
# 397          K06             West Falls Church-VT/UVA   20
# 307          K06             West Falls Church-VT/UVA   11
# 404          E07                     West Hyattsville   22
# 88           E07                     West Hyattsville    2
# 171          E07                     West Hyattsville    5
# 303          E07                     West Hyattsville   11
# 103          B10                              Wheaton    3
# 406          B10                              Wheaton   23
# 372          B10                              Wheaton   16
# 71           A12                          White Flint    2
# 98           A12                          White Flint    3
# 231          A12                          White Flint    8
# 252          A12                          White Flint    9
# 333          A12                          White Flint   13
# 130          A12                          White Flint    4
# 69           N06                   Wiehle-Reston East    2
# 68           N06                   Wiehle-Reston East    2
# 126          A04        Woodley Park-Zoo/Adams Morgan    4
# 271          A04        Woodley Park-Zoo/Adams Morgan   10
# 41           A04        Woodley Park-Zoo/Adams Morgan    1
# 347          A04        Woodley Park-Zoo/Adams Morgan   14
# 203          A04        Woodley Park-Zoo/Adams Morgan    7
# 399          A04        Woodley Park-Zoo/Adams Morgan   21
#
# [447 rows x 9 columns]

# %%
trains_by_location = z.groupby('LocationName')

# %%
descriptions = trains_by_location.describe()

# %%
descriptions.Min[:4]
# Out:
# LocationName
# Addison Road-Seat Pleasant  count      6
#                             unique     6
#                             top       14
#                             freq       1
# Name: Min, dtype: object

# %%
descriptions.Min[4:8]
# Out:
# LocationName
# Anacostia     count     4
#               unique    3
#               top       9
#               freq      2
# Name: Min, dtype: object

# %%
descriptions.Min[8:12]
# Out:
# LocationName
# Archives-Navy Memorial-Penn Quarter  count     6
#                                      unique    6
#                                      top       4
#                                      freq      1
# Name: Min, dtype: object

# %%
anacostia_arrivals = z[z['LocationName']=='Anacostia']

# %%
import matplotlib

# %%
anacostia_arrivals.sort_values(['DestinationName'])
# Out:
#     Car Destination DestinationCode DestinationName Group Line LocationCode  \
# 261   6    Brnch Av             F11      Branch Ave     2   GR          F06
# 424   6    Brnch Av             F11      Branch Ave     2   GR          F06
# 260   6     Grnbelt             E10       Greenbelt     1   GR          F06
# 386   -       Train            None           Train     2   --          F06
#
#     LocationName Min
# 261    Anacostia   9
# 424    Anacostia  29
# 260    Anacostia   9
# 386    Anacostia  18

# %%
# If I am at U St heading to Braddock Rd, is it faster to wait for Yellow line?
# or take Green to L'Enfant and transfer to Blue line?
U_street_trains = z[z['LocationName']=="U Street/African-Amer Civil War Memorial/Cardozo"]
# Yellow line to Franconia-Springfield or Huntington will get me to Braddock Rd
huntington_bound = U_street_trains[U_street_trains['DestinationName']=='Huntington']
franconia_bound = U_street_trains[U_street_trains['DestinationName']=='Franconia-Springfield']

# %%
U_street_trains
# Out:
#     Car Destination DestinationCode DestinationName Group Line LocationCode  \
# 59    6     Grnbelt             E10       Greenbelt     1   GR          E03
# 143   -       Train            None           Train     2   --          E03
# 169   6    Ft.Tottn             E06     Fort Totten     1   YL          E03
# 195   6    Hntingtn             C15      Huntington     2   YL          E03
# 323   6     Grnbelt             E10       Greenbelt     1   GR          E03
# 365   6    Brnch Av             F11      Branch Ave     2   GR          E03
#
#                                          LocationName Min
# 59   U Street/African-Amer Civil War Memorial/Cardozo   1
# 143  U Street/African-Amer Civil War Memorial/Cardozo   4
# 169  U Street/African-Amer Civil War Memorial/Cardozo   5
# 195  U Street/African-Amer Civil War Memorial/Cardozo   6
# 323  U Street/African-Amer Civil War Memorial/Cardozo  12
# 365  U Street/African-Amer Civil War Memorial/Cardozo  15

# %%
df_new = pd.concat([huntington_bound, franconia_bound])
df_new
# Out:
#     Car Destination DestinationCode DestinationName Group Line LocationCode  \
# 195   6    Hntingtn             C15      Huntington     2   YL          E03
#
#                                          LocationName Min
# 195  U Street/African-Amer Civil War Memorial/Cardozo   6
